# %%
# Bibliotecas
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from tqdm.auto import tqdm
import re
import nltk

# Configuración de NLTK
for recurso in ['punkt', 'stopwords']:
    nltk.download(recurso)
palabras_vacias = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\galot\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\galot\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Configuración para web scraping
URL_BASE = "https://www.allrecipes.com/recipes-a-z-6735880"
CABECERAS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/131.0.0.0",
    "Accept": "text/html,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1"
}

# %%
def extraer_recetas():
    """Extrae las recetas del sitio web y retorna un DataFrame"""
    recetas_datos = []
    
    # Obtener página principal
    respuesta = requests.get(URL_BASE, headers=CABECERAS)
    
    if respuesta.status_code != 200:
        raise Exception(f"Error de acceso: {respuesta.status_code}")
        
    sopa = BeautifulSoup(respuesta.text, 'html.parser')
    elementos_principales = sopa.find_all('li', class_='mntl-link-list__item')
    
    for elemento in tqdm(elementos_principales, desc="Extrayendo recetas"):
        enlace = elemento.find('a')
        if not enlace:
            continue
            
        categoria = enlace.get_text(strip=True)
        url_categoria = enlace['href']
        
        # Procesar página de categoría
        resp_categoria = requests.get(url_categoria, headers=CABECERAS)
        if resp_categoria.status_code == 200:
            sopa_categoria = BeautifulSoup(resp_categoria.text, 'html.parser')
            recetas = sopa_categoria.find_all('a', class_='comp mntl-card-list-items mntl-universal-card mntl-document-card mntl-card card card--no-image')
            
            for receta in recetas:
                recetas_datos.append({
                    'Categoria': categoria,
                    'URL_Categoria': url_categoria,
                    'Nombre_Receta': receta.get_text(strip=True),
                    'URL_Receta': receta.get('href', '')
                })
    
    return pd.DataFrame(recetas_datos)

# Extracción
df_recetas = extraer_recetas()
df_recetas = df_recetas[:600]
# Out:
# Extrayendo recetas:   0%|          | 0/378 [00:00<?, ?it/s]

# %%
def extraer_detalles_receta(url):
    """
    Extrae los detalles específicos de una receta
    """
    try:
        respuesta = requests.get(url, headers=CABECERAS)
        respuesta.raise_for_status()
        sopa = BeautifulSoup(respuesta.content, 'html.parser')
        
        # Extraer nombre
        titulo = sopa.find('h1', class_='article-heading text-headline-400')
        nombre = titulo.get_text(strip=True) if titulo else 'Sin título'
        
        # Extraer ingredientes
        lista_ingredientes = []
        elementos_ingredientes = sopa.find_all('li', class_='mm-recipes-structured-ingredients__list-item')
        
        for elemento in elementos_ingredientes:
            partes = {
                'cantidad': elemento.find('span', {'data-ingredient-quantity': 'true'}),
                'unidad': elemento.find('span', {'data-ingredient-unit': 'true'}),
                'ingrediente': elemento.find('span', {'data-ingredient-name': 'true'})
            }
            
            ingrediente_completo = ' '.join(
                parte.get_text(strip=True) if parte else ''
                for parte in partes.values()
            ).strip()
            
            if ingrediente_completo:
                lista_ingredientes.append(ingrediente_completo)
                
        # Extraer preparación
        pasos_preparacion = []
        seccion_preparacion = sopa.find('ol', class_='comp mntl-sc-block mntl-sc-block-startgroup mntl-sc-block-group--OL')
        
        if seccion_preparacion:
            pasos_preparacion = [paso.get_text(strip=True) 
                               for paso in seccion_preparacion.find_all('li')]
        
        return {
            'nombre': nombre,
            'ingredientes': ', '.join(lista_ingredientes),
            'preparacion': ' '.join(pasos_preparacion)
        }
        
    except Exception as error:
        print(f"Error en URL {url}: {str(error)}")
        return {
            'nombre': 'Error',
            'ingredientes': 'Error',
            'preparacion': 'Error'
        }


def actualizar_recetas(df):
    """
    Actualiza el DataFrame con los detalles de cada receta
    """
    for indice in tqdm(df.index, desc="Procesando recetas"):
        detalles = extraer_detalles_receta(df.loc[indice, 'URL_Receta'])
        for campo, valor in detalles.items():
            df.loc[indice, campo.capitalize()] = valor
    
    return df

# Ejecutar 
df_recetas = actualizar_recetas(df_recetas)
df_recetas.to_excel('recetas_completasx.xlsx', index=False)
# Out:
# Procesando recetas:   0%|          | 0/600 [00:00<?, ?it/s]

# %%
class ProcesadorRecetas:
    def __init__(self):
        self.vectorizador = TfidfVectorizer(max_features=1000)
        self.modelo_clustering = KMeans(n_clusters=10, random_state=42)
        
    def limpiar_texto(self, texto):
        """Preprocesa y limpia el texto"""
        # Convertir a minúsculas y eliminar caracteres especiales
        texto = texto.lower()
        texto = re.sub(r'[^a-zA-Z]', ' ', texto)
        
        # Tokenización y eliminación de palabras vacías
        tokens = word_tokenize(texto)
        tokens_filtrados = [palabra for palabra in tokens 
                          if palabra not in palabras_vacias and len(palabra) > 2]
        
        return ' '.join(tokens_filtrados)
    
    def preparar_datos(self, df):
        """Prepara los datos para el análisis"""
        # Combinar textos y limpiar
        df['texto_completo'] = df['Ingredientes'].fillna('') + ' ' + df['Preparacion'].fillna('')
        df['texto_procesado'] = df['texto_completo'].apply(self.limpiar_texto)
        
        # Generar embeddings
        self.embeddings = self.vectorizador.fit_transform(df['texto_procesado'])
        
        # Realizar clustering
        df['cluster'] = self.modelo_clustering.fit_predict(self.embeddings)
        
        return df

# Inicializar procesador y ejecutar
procesador = ProcesadorRecetas()
df_recetas = procesador.preparar_datos(df_recetas)

# %%
class BuscadorRecetas:
    def __init__(self, procesador, df):
        self.procesador = procesador
        self.df = df
    
    def buscar_similares(self, consulta, n_resultados=10):
        """Busca recetas similares a la consulta"""
        consulta_limpia = self.procesador.limpiar_texto(consulta)
        consulta_vector = self.procesador.vectorizador.transform([consulta_limpia])
        similitudes = cosine_similarity(consulta_vector, self.procesador.embeddings).flatten()
        indices_mejores = similitudes.argsort()[-n_resultados:][::-1]
        
        resultados = []
        for idx in indices_mejores:
            receta = self.df.iloc[idx]
            resultados.append({
                'nombre': receta['Nombre'],
                'similitud': similitudes[idx],
                'cluster': receta['cluster'],
                'ingredientes': receta['Ingredientes'],
                'preparacion': receta['Preparacion'],
                'url': receta['URL_Receta']
            })
        return resultados

    def formatear_receta(self, receta, indice):
        """Formatea una receta individual con estilo ASCII art"""
        similitud_porcentaje = receta['similitud'] * 100
        barra_similitud = '█' * int(similitud_porcentaje/10) + '░' * (10 - int(similitud_porcentaje/10))
        
        formato = f"""
╔══════════════════════ RECETA {indice} ══════════════════════╗
║ {receta['nombre']:<48} ║
╠══════════════════════════════════════════════════════════════╣
║ Similitud: [{barra_similitud}] {similitud_porcentaje:.1f}%
║ Grupo de recetas: {receta['cluster']}
║ 
║ 🥘 INGREDIENTES:
"""
        # Formatear ingredientes
        ingredientes = receta['ingredientes'].split(',')
        for ing in ingredientes:
            if ing.strip():
                formato += f"║   • {ing.strip()[:45]:<45} ║\n"
        
        formato += "║\n║ 👩‍🍳 PREPARACIÓN:\n"
        
        # Formatear pasos de preparación
        pasos = receta['preparacion'].split('.')
        for i, paso in enumerate(pasos, 1):
            if paso.strip():
                # Dividir pasos largos en múltiples líneas
                palabras = paso.strip().split()
                linea_actual = f"║   {i}. "
                for palabra in palabras:
                    if len(linea_actual + palabra) > 45:
                        formato += f"{linea_actual:<50} ║\n"
                        linea_actual = f"║      {palabra}"
                    else:
                        linea_actual += f"{palabra} "
                if linea_actual.strip():
                    formato += f"{linea_actual:<50} ║\n"
        
        formato += "║\n║ 🔗 URL: " + receta['url'][:45] + "\n"
        formato += "╚══════════════════════════════════════════════════════════════╝"
        return formato

    def mostrar_resultados(self, consulta):
        """Muestra los resultados con formato personalizado"""
        resultados = self.buscar_similares(consulta)
        print(f"\n🔍 Búsqueda: '{consulta}'\n")
        print("📊 Encontradas las siguientes recetas similares:\n")
        
        for i, resultado in enumerate(resultados, 1):
            print(self.formatear_receta(resultado, i))
            if i < len(resultados):
                print("\n" + "▫" * 60 + "\n")

# Crear buscador y ejecutar ejemplo
buscador = BuscadorRecetas(procesador, df_recetas)
buscador.mostrar_resultados("pan de chocolate")
# Out:
# 🔍 Búsqueda: 'pan de chocolate'
#
# 📊 Encontradas las siguientes recetas similares:
#
#
# ╔══════════════════════ RECETA 1 ══════════════════════╗
# ║ White Chocolate Cinnamon Toast Crunch Bars       ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [█████░░░░░] 55.8%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • 3 1/4 cups white chocolate chips              ║
# ║   • 2 teaspoons ground cinnamon                   ║
# ║   • 1 cup innamon Toast Crunch                    ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Melt 3 cups white chocolate in a            ║
# ║      doubleboiler or place in a                  ║
# ║      microwave-safebowl and microwave in         ║
# ║      30-secondintervals, stirring between        ║
# ║      intervalsuntil melted                       ║
# ║   2. Add cinnamon; stir to combine               ║
# ║   3. In a 12-well silicone snack bar pan:        ║
# ║      Place3-6 cereal pieces in each well         ║
# ║   4. Spoon chocolate over cereal                 ║
# ║   5. Immediately place 3-6 more cereal           ║
# ║      pieceson top of chocolate                   ║
# ║   6. Sprinkle remaining chocolate chips          ║
# ║      evenlyover the wells                        ║
# ║   7. White chocolate hardens quickly, so         ║
# ║      actfast as you're assembling the candy      ║
# ║      bars                                        ║
# ║   8. Annie Campbell                              ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/white-chocolate-ci
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 2 ══════════════════════╗
# ║ Samoa Cookie Bars                                ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [████░░░░░░] 43.3%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • cooking spray                                 ║
# ║   • 1 ½ cups flour                                ║
# ║   • 1 tablespoon cornstarch                       ║
# ║   • ½ teaspoon baking powder                      ║
# ║   • ½ teaspoon salt                               ║
# ║   • ½ cup butter                                  ║
# ║   • softened                                      ║
# ║   • ¼ cup white sugar                             ║
# ║   • ¼ cup packed brown sugar                      ║
# ║   • 1 large egg yolk                              ║
# ║   • 1 teaspoon vanilla extract                    ║
# ║   • 1 (13.4 ounce) can dulce de leche             ║
# ║   • 3 tablespoons milk                            ║
# ║   • 1 (14 ounce) package sweetened flaked coconut ║
# ║   • 1 (12 ounce) bag semisweet chocolate chips    ║
# ║   • divided                                       ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Preheat the oven to 350 degrees F (175      ║
# ║      degreesC)                                   ║
# ║   2. Line a 9x13-inch baking pan with foil,      ║
# ║      extendingfoil over edges                    ║
# ║   3. Coat foil with cooking spray                ║
# ║   4. For crust, stir together flour,             ║
# ║      cornstarch,baking powder, and salt in       ║
# ║      asmall bowl                                 ║
# ║   5. Beat butter in a large bowl with an         ║
# ║      electricmixer at medium speed for 30        ║
# ║      seconds                                     ║
# ║   6. Add both sugars and beat until light        ║
# ║      andfluffy at medium-high speed              ║
# ║   7. Beat in egg yolk and vanilla extract        ║
# ║   8. Beat in flour mixture (mixture will be      ║
# ║      crumbly)                                    ║
# ║   9. Press dough onto the bottom of the          ║
# ║      preparedpan                                 ║
# ║   10. Bake crust in the preheated oven           ║
# ║      untiledges are light brown, 10 to 12        ║
# ║      minutes                                     ║
# ║   11. Meanwhile, combine dulce de leche and      ║
# ║      milkin a medium bowl                        ║
# ║   12. Stir in flaked coconut                     ║
# ║   13. Sprinkle 1 1/2 cups chocolate chips        ║
# ║      overthe hot crust; let stand for 5          ║
# ║      minutesuntil chocolate has melted           ║
# ║   14. Spread melted chocolate over crust in      ║
# ║      aneven layer                                ║
# ║   15. Carefully spread coconut mixture over      ║
# ║      chocolatelayer                              ║
# ║   16. Return to the oven and bake 10             ║
# ║      minutesmore                                 ║
# ║   17. Cool in the pan on a wire rack             ║
# ║   18. Microwave remaining chocolate chips        ║
# ║      ina small bowl, stirring once halfway       ║
# ║      through,until melted and smooth, 30 to      ║
# ║      45seconds                                   ║
# ║   19. Drizzle melted chocolate over coconut      ║
# ║      mixture                                     ║
# ║   20. Chill, covered, until set, about 1         ║
# ║      hour                                        ║
# ║   21. Using foil, lift out uncut cookies         ║
# ║   22. Cut into bars                              ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/recipe/8535610/sam
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 3 ══════════════════════╗
# ║ Caramel Shortbread Squares                       ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [███░░░░░░░] 36.3%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • 1 ¼ cups all-purpose flour                    ║
# ║   • ⅔ cup unsalted butter                         ║
# ║   • softened                                      ║
# ║   • ¼ cup white sugar                             ║
# ║   • ½ cup unsalted butter                         ║
# ║   • ½ cup packed light brown sugar                ║
# ║   • ½ cup sweetened condensed milk                ║
# ║   • 2 tablespoons light corn syrup                ║
# ║   • 1 ¼ cups milk chocolate chips                 ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Preheat the oven to 350 degrees F (175      ║
# ║      C)                                          ║
# ║   2. To make the shortbread: Mix flour,          ║
# ║      softenedbutter, and sugar together in       ║
# ║      amedium bowl until well blended and         ║
# ║      crumbly                                     ║
# ║   3. Press into the bottom of a 9-inch           ║
# ║      squarebaking pan                            ║
# ║   4. Bake in the preheated oven until dry        ║
# ║      andlight golden brown, about 20             ║
# ║      minutes                                     ║
# ║   5. To make the caramel: Bring butter,          ║
# ║      brownsugar, condensed milk, and corn        ║
# ║      syrupto a boil in a saucepan over           ║
# ║      medium-lowheat                              ║
# ║   6. Boil for 5 minutes, then remove from        ║
# ║      theheat and beat vigorously with a          ║
# ║      woodenspoon for about 3 minutes             ║
# ║   7. Pour over baked crust (crust can be         ║
# ║      eitherwarm or cool)                         ║
# ║   8. Let sit at room temperature until           ║
# ║      caramelbegins to firm up, 2 to 3 hours      ║
# ║   9. Microwave chocolate in a                    ║
# ║      microwave-safebowl on high for 1            ║
# ║      minute,then stir and continue to heat       ║
# ║      andstir in 20-second intervals until        ║
# ║      chocolateis melted and smooth               ║
# ║   10. Pour chocolate over caramel layer and      ║
# ║      spreadevenly to cover completely            ║
# ║   11. Chill in the refrigerator until            ║
# ║      chocolateis set, about 30 minutes           ║
# ║   12. Cut into bars                              ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/recipe/15347/caram
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 4 ══════════════════════╗
# ║ Chocolate Peanut Butter Protein Bars             ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [███░░░░░░░] 35.8%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • 3/4 cup peanut butter                         ║
# ║   • 1/2 cup vanilla protein powder                ║
# ║   • 2 tablespoons maple syrup                     ║
# ║   • 1 teaspoon vanilla extract                    ║
# ║   • 1/8 teaspoon salt                             ║
# ║   • 1/2 cup semisweet chocolate chips             ║
# ║   • 1 teaspoon coconut oil                        ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Line an 8 1/2x4 1/2-inch loaf pan with      ║
# ║      parchmentpaper, leaving overhang on         ║
# ║      allsides to make it easy to remove          ║
# ║      barsfrom the pan                            ║
# ║   2. Set aside                                   ║
# ║   3. Place peanut butter, protein powder,        ║
# ║      maplesyrup, vanilla and salt in a bowl      ║
# ║      andmix until well combined; press into      ║
# ║      theprepared pan                             ║
# ║   4. Set aside                                   ║
# ║   5. Place chocolate chips and oil in a          ║
# ║      microwavesafe bowl                          ║
# ║   6. Microwave for 30 seconds, stir              ║
# ║   7. Repeat until chips are completely           ║
# ║      meltedwhen stirred                          ║
# ║   8. Pour over bars, smooth chocolate            ║
# ║   9. Refrigerate until set, about 30             ║
# ║      minutes                                     ║
# ║   10. Cut into 8 bars                            ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/chocolate-peanut-b
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 5 ══════════════════════╗
# ║ MMMMM... Brownies                                ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [███░░░░░░░] 35.0%
# ║ Grupo de recetas: 6
# ║
# ║ 🥘 INGREDIENTES:
# ║   • ½ cup white sugar                             ║
# ║   • 2 tablespoons butter                          ║
# ║   • 2 tablespoons water                           ║
# ║   • 1 ½ cups semisweet chocolate chips            ║
# ║   • 2 large eggs                                  ║
# ║   • beaten                                        ║
# ║   • ½ teaspoon vanilla extract                    ║
# ║   • ⅔ cup all-purpose flour                       ║
# ║   • ½ teaspoon salt                               ║
# ║   • ¼ teaspoon baking soda                        ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Gather all ingredients                      ║
# ║   2. Dotdash Meredith Food Studios Preheat       ║
# ║      theoven to 325 degrees F (165 degrees       ║
# ║      C)                                          ║
# ║   3. Grease an 8-inch square pan                 ║
# ║   4. Combine sugar, butter, and water in a       ║
# ║      mediumsaucepan; cook and stir over          ║
# ║      mediumheat until boiling                    ║
# ║   5. Remove from heat and stir in chocolate      ║
# ║      chipsuntil melted and smooth; mix in        ║
# ║      eggsand vanilla                             ║
# ║   6. Combine flour, salt, and baking soda;       ║
# ║      stirinto the chocolate mixture              ║
# ║   7. Spread brownie batter evenly into the       ║
# ║      preparedpan                                 ║
# ║   8. Dotdash Meredith Food StudiosDotdash        ║
# ║      MeredithFood Studios Bake in the            ║
# ║      preheatedoven until top is dry and          ║
# ║      edgeshave started to pull away from         ║
# ║      thesides of the pan, about 20 to 30         ║
# ║      minutes                                     ║
# ║   9. Let cool completely before cutting          ║
# ║      intosquares                                 ║
# ║   10. DOTDASH MEREDITH FOOD STUDIOS              ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/recipe/25080/mmmmm
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 6 ══════════════════════╗
# ║ Peppermint Mocha Cookie Bars                     ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [███░░░░░░░] 34.0%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • 1/2 cup white chocolate chips                 ║
# ║   • 1/3 cup heavy cream                           ║
# ║   • 1/8 teaspoon peppermint extract               ║
# ║   • 2 tablespoons instant espresso powder         ║
# ║   • 2 tablespoons water                           ║
# ║   • 1 cup all-purpose flour                       ║
# ║   • 1/4 cup unsweetened cocoa powder              ║
# ║   • 1/2 teaspoon salt                             ║
# ║   • 1/2 teaspoon baking soda                      ║
# ║   • 1/2 teaspoon baking powder                    ║
# ║   • 1/2 cup unsalted butter                       ║
# ║   • softened                                      ║
# ║   • 1/2 cup white sugar                           ║
# ║   • 1/4 cup dark brown sugar                      ║
# ║   • 1 large egg                                   ║
# ║   • at room temperature                           ║
# ║   • 1 1/2 teaspoons vanilla extract               ║
# ║   • 1/2 teaspoon peppermint extract               ║
# ║   • 1/2 cup dark chocolate chips                  ║
# ║   • 1/4 cup candy canes                           ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Place white chocolate chips, heavy          ║
# ║      cream,and 1/8 teaspoon peppermint           ║
# ║      extractinto a microwave-safe bowl           ║
# ║   2. Microwave at 50% power in 30 second         ║
# ║      intervals,stirring after each               ║
# ║      interval,until melted and combined          ║
# ║   3. Place mixture, uncovered, in the            ║
# ║      refrigeratoruntil completely chilled,       ║
# ║      about1 hour                                 ║
# ║   4. Preheat the oven to 350 degrees F (175      ║
# ║      degreesC)                                   ║
# ║   5. Line an 8x8-inch square pan with            ║
# ║      enoughparchment paper to have overhang      ║
# ║      onall sides                                 ║
# ║   6. In a small bowl or measuring cup, stir      ║
# ║      espressopowder and hot water together       ║
# ║      untildissolved                              ║
# ║   7. In a medium bowl, whisk together            ║
# ║      flour,cocoa powder, salt, baking soda,      ║
# ║      andbaking powder until thoroughly           ║
# ║      combined                                    ║
# ║   8. Beat butter, white sugar, and brown         ║
# ║      sugartogether in a large bowl until         ║
# ║      lightand fluffy                             ║
# ║   9. Add in egg and beat until thoroughly        ║
# ║      combined                                    ║
# ║   10. Add in espresso mixture, vanilla           ║
# ║      extract,and 1/2 teaspoon peppermint         ║
# ║      extractand mix until combined               ║
# ║   11. Pour in half of the flour mixture and      ║
# ║      mixuntil just combined                      ║
# ║   12. Add in remaining flour mixture and         ║
# ║      mixuntil just combined—dough will be        ║
# ║      somewhatthick                               ║
# ║   13. Stir in chocolate chips and crushed        ║
# ║      candycanes                                  ║
# ║   14. Spread dough into the prepared pan in      ║
# ║      aneven layer                                ║
# ║   15. Bake in the preheated oven until the       ║
# ║      barslook just set, 25 to 30 minutes         ║
# ║   16. Remove from the oven and allow to          ║
# ║      coolcompletely in the pan, about 30         ║
# ║      minutes                                     ║
# ║   17. Remove chilled white chocolate             ║
# ║      mixturefrom the fridge                      ║
# ║   18. Whip on medium-high speed with an          ║
# ║      electricmixer until mixture holds           ║
# ║      stiffpeaks                                  ║
# ║   19. Spread white chocolate frosting in a       ║
# ║      thineven layer over the top of the          ║
# ║      cooledbars and sprinkle with                ║
# ║      additionalcrushed candy canes               ║
# ║   20. Cut into 16 bars                           ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/peppermint-mocha-c
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 7 ══════════════════════╗
# ║ Chef John's Banana Bread                         ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [███░░░░░░░] 32.6%
# ║ Grupo de recetas: 2
# ║
# ║ 🥘 INGREDIENTES:
# ║   • cooking spray                                 ║
# ║   • 2 cups all-purpose flour                      ║
# ║   • 1 teaspoon baking powder                      ║
# ║   • 1 teaspoon baking soda                        ║
# ║   • 1 teaspoon salt                               ║
# ║   • 1 cup white sugar                             ║
# ║   • ½ cup butter                                  ║
# ║   • softened                                      ║
# ║   • 3  ripe bananas                               ║
# ║   • mashed                                        ║
# ║   • 2 large eggs                                  ║
# ║   • 1 tablespoon milk                             ║
# ║   • ¼ teaspoon vanilla extract                    ║
# ║   • 1 cup chopped walnuts                         ║
# ║   • ⅓ cup semisweet chocolate chips               ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Preheat the oven to 325 degrees F (165      ║
# ║      degreesC)                                   ║
# ║   2. Coat a 9x4-inch loaf pan with cooking       ║
# ║      spray                                       ║
# ║   3. Whisk together flour, baking powder,        ║
# ║      bakingsoda, and salt in a medium bowl;      ║
# ║      setaside                                    ║
# ║   4. Beat together sugar and butter with an      ║
# ║      electricmixer in a large bowl until         ║
# ║      smooth                                      ║
# ║   5. Add mashed bananas and mix until            ║
# ║      combined                                    ║
# ║   6. Add eggs, one at a time, beating well       ║
# ║      aftereach addition                          ║
# ║   7. Stir in milk and vanilla                    ║
# ║   8. Stir in flour mixture, walnuts, and         ║
# ║      chocolatechips until just incorporated      ║
# ║   9. Pour batter into the prepared loaf pan      ║
# ║   10. Tap pan on the counter to release any      ║
# ║      airpockets                                  ║
# ║   11. Bake in the preheated oven until a         ║
# ║      toothpickinserted into the center           ║
# ║      comesout clean, about 1 hour and 10         ║
# ║      minutes                                     ║
# ║   12. Let rest in the pan for 15 to 20           ║
# ║      minutes                                     ║
# ║   13. Remove bread from the pan, then slice      ║
# ║      andserve                                    ║
# ║   14. ArmyRD                                     ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/recipe/219967/chef
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 8 ══════════════════════╗
# ║ Hello Dolly Bars                                 ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [███░░░░░░░] 30.9%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • 1 ½ cups graham cracker crumbs                ║
# ║   • ½ cup butter                                  ║
# ║   • melted                                        ║
# ║   • 1 (14 ounce) can sweetened condensed milk     ║
# ║   • 1 ½ cups semisweet chocolate chips            ║
# ║   • 1 cup chopped walnuts                         ║
# ║   • 1 cup shredded coconut                        ║
# ║   • ½ cup white chocolate chips                   ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Preheat the oven to 325 degrees F (165      ║
# ║      degreesC)                                   ║
# ║   2. Mix graham cracker crumbs and melted        ║
# ║      buttertogether in a bowl until evenly       ║
# ║      moistened;press into the bottom of a        ║
# ║      9x13-inchbaking dish                        ║
# ║   3. Pour 1/2 of the can of sweetened            ║
# ║      condensedmilk over the graham cracker       ║
# ║      crust                                       ║
# ║   4. Sprinkle semisweet chocolate chips,         ║
# ║      walnuts,coconut, and white chocolate        ║
# ║      chipsover the graham cracker crust;         ║
# ║      gentlypress chocolate, nuts, and            ║
# ║      coconutsinto the crust                      ║
# ║   5. Drizzle remaining 1/2 can of condensed      ║
# ║      milkover the top                            ║
# ║   6. Bake in the preheated oven until            ║
# ║      fragrantand coconut is golden, 25 to        ║
# ║      30minutes                                   ║
# ║   7. Cool completely before cutting into         ║
# ║      squares                                     ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/recipe/235142/hell
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 9 ══════════════════════╗
# ║ Christmas Cookie Bars                            ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [██░░░░░░░░] 30.0%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • 1/2 cup unsalted butter                       ║
# ║   • melted                                        ║
# ║   • 3/4 cup dark brown sugar                      ║
# ║   • 2 tablespoons white sugar                     ║
# ║   • 1/2 teaspoon salt                             ║
# ║   • 1/8 teaspoon ground nutmeg                    ║
# ║   • 1  extra large egg                            ║
# ║   • 2 teaspoons vanilla extract                   ║
# ║   • 1 1/2 cups all-purpose flour                  ║
# ║   • 1/2 teaspoon baking soda                      ║
# ║   • 1/2 cup dark chocolate chips                  ║
# ║   • 1/2 cup M&Ms                                  ║
# ║   • 2 tablespoons sprinkles                       ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Preheat the oven to 350 degrees F (180      ║
# ║      degreesC)                                   ║
# ║   2. Line an 8x8-inch square pan with            ║
# ║      enoughparchment paper to have overhang      ║
# ║      onall sides                                 ║
# ║   3. Whisk melted butter, brown sugar,           ║
# ║      whitesugar, salt, and nutmeg together       ║
# ║      ina large bowl until thoroughly             ║
# ║      combined                                    ║
# ║   4. Add in egg and vanilla and mix until        ║
# ║      thoroughlyincorporated                      ║
# ║   5. Add in flour and baking soda and mix        ║
# ║      untiljust combined                          ║
# ║   6. Fold in chocolate chips, M&Ms, and          ║
# ║      sprinkles                                   ║
# ║   7. Transfer batter into the prepared pan       ║
# ║      andspread into an even layer                ║
# ║   8. Sprinkle a few more chocolate chips,        ║
# ║      M&Ms,and sprinkles evenly over the top      ║
# ║      ofthe batter                                ║
# ║   9. Bake in the preheated oven until bars       ║
# ║      arepuffed and begin to turn golden          ║
# ║      brownon top, 30 to 35 minutes               ║
# ║   10. Remove from the oven; cool completely      ║
# ║      beforecutting into bars                     ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/christmas-cookie-b
# ╚══════════════════════════════════════════════════════════════╝
#
# ▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫▫
#
#
# ╔══════════════════════ RECETA 10 ══════════════════════╗
# ║ Chocolate Angel Food Cake II                     ║
# ╠══════════════════════════════════════════════════════════════╣
# ║ Similitud: [██░░░░░░░░] 26.2%
# ║ Grupo de recetas: 9
# ║
# ║ 🥘 INGREDIENTES:
# ║   • ¾ cup cake flour                              ║
# ║   • ¼ cup unsweetened cocoa powder                ║
# ║   • 1 ½ cups white sugar                          ║
# ║   • 3 (1 ounce) squares semisweet chocolate       ║
# ║   • grated                                        ║
# ║   • 12  egg whites                                ║
# ║   • 1 teaspoon cream of tartar                    ║
# ║   • ¼ teaspoon salt                               ║
# ║   • ¼ teaspoon vanilla extract                    ║
# ║   • 1 ½ teaspoons lemon juice                     ║
# ║   • confectioners' sugar for dusting              ║
# ║
# ║ 👩‍🍳 PREPARACIÓN:
# ║   1. Preheat oven to 325 degrees F (165          ║
# ║      degreesC)                                   ║
# ║   2. If it does not have a removable             ║
# ║      bottom,line a 9 inch tube pan with          ║
# ║      parchmentpaper                              ║
# ║   3. Sift together the flour, cocoa and 3/4      ║
# ║      cupof the sugar                             ║
# ║   4. Set aside                                   ║
# ║   5. Measure 3 tablespoons of the flour          ║
# ║      mixtureand toss with the grated             ║
# ║      chocolate                                   ║
# ║   6. In a large bowl, using an electric          ║
# ║      mixerset at low speed, beat egg whites      ║
# ║      untilfoamy                                  ║
# ║   7. Increase mixer speed to medium, stir        ║
# ║      incream of tartar and salt, and             ║
# ║      continueto beat until egg whites form       ║
# ║      softpeaks                                   ║
# ║   8. Gradually mix in the remaining 3/4 cup      ║
# ║      sugarand beat until stiff peaks form        ║
# ║   9. Stir in the vanilla and lemon juice         ║
# ║   10. Gently fold the flour mixture into         ║
# ║      thebeaten egg whites, then fold in the      ║
# ║      gratedchocolate, stirring just until        ║
# ║      nowhite streaks remain                      ║
# ║   11. Gently scrape the batter into the          ║
# ║      preparedpan                                 ║
# ║   12. Smooth the surface of the batter and       ║
# ║      tapthe pan lightly to remove any air        ║
# ║      bubbles                                     ║
# ║   13. Bake in center of the preheated oven       ║
# ║      for60 minutes, or until the surface         ║
# ║      springsback when touched                    ║
# ║   14. Cool completely, and sprinkle with         ║
# ║      confectioners'sugar before serving, if      ║
# ║      desired                                     ║
# ║
# ║ 🔗 URL: https://www.allrecipes.com/recipe/23733/choco
# ╚══════════════════════════════════════════════════════════════╝
